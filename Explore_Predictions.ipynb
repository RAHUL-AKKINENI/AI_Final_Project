# %%
import visualize_prediction as V
import pandas as pd

# %%
STARTER_IMAGES=True
PATH_TO_IMAGES = "starter_images/"
PATH_TO_MODEL = "pretrained/checkpoint"
LABEL = "Infiltration"
POSITIVE_FINDINGS_ONLY = True

# %%
dataloader,model = V.load_data(PATH_TO_IMAGES,LABEL,PATH_TO_MODEL,POSITIVE_FINDINGS_ONLY,STARTER_IMAGES)
print("Cases for review:")
print(len(dataloader))
# Out:
# Cases for review:
# 123

# %%
preds = V.show_next(dataloader,model, LABEL)
preds
# Out:
#                    Predicted Probability  Ground Truth
# Finding
# Effusion                           0.730          True
# Atelectasis                        0.447          True
# Infiltration                       0.101          True
# Pleural_Thickening                 0.051         False
# Nodule                             0.045         False
# Pneumothorax                       0.044         False
# Consolidation                      0.034         False
# Fibrosis                           0.024         False
# Emphysema                          0.023         False
# Mass                               0.020         False
# Pneumonia                          0.016         False
# Edema                              0.009         False
# Hernia                             0.004         False
# Cardiomegaly                       0.002         False
